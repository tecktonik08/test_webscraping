# %%
from selenium import webdriver

# %%
# !python -m pip install selenium

# %% [markdown]
# Install 후 아래 코드를 입력해줘야 실행됨

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !dir .\chromedriver.exe
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 5E33-8C77
#
#  C:\Develops\test_webscraping 디렉터리
#
# 2021-06-08  오전 11:07        11,107,328 chromedriver.exe
#                1개 파일          11,107,328 바이트
#                0개 디렉터리  26,400,493,568 바이트 남음

# %% [markdown]
# request와 같음 -> chrome 창을 엶

# %%
driver = webdriver.Chrome('./chromedriver.exe')

# %% [markdown]
# 네이버 요청 -> 네이버로 접속됨

# %%
driver.get('https://www.naver.com')

# %% [markdown]
# 네이버 페이지의 소스를 긁어옴

# %%
driver.page_source
# Out:
# '<html lang="ko" data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36"><head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"> <meta name="robots" content="index,nofollow"> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/
# ...
